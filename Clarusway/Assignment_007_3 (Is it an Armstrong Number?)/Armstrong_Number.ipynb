# %% [markdown]
# <a href="https://colab.research.google.com/github/mehmetcolgecen/python-addict/blob/main/Clarusway/Assignment_007_3%20(Is%20it%20an%20Armstrong%20Number%3F)/Armstrong_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Task:**
#
# Find out if a given number is an "**Armstrong Number**".
#
# *   An n-digit number that is the sum of the nth powers of its digits is called an n-Armstrong number. Examples :
#
#     1. 371 = 33 + 73 + 13;
#     2. 9474 = 94 + 44 + 74 + 44;
#     3. 93084 = 95 + 35 + 05 + 85 + 45.
#
# *   Write a Python program that;
#     1. Takes a positive integer number from the user,
#     2. Checks the entered number if it is Armstrong,
#     3. Consider the negative, float and any entries other than numeric values then display a warning message to the user.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
new_number = 0
while True:
    try:
        number = int(input("Please Enter a Number to Check if it is a Armstrong Number: "))
        assert(number > 0)
        break
    except:
        print("It is an invalid entry. Don't use non-numeric, float, or negative values!")

digit = len(str(number))

for i in str(number):
    new_number += int(i)**digit

if number == new_number:
    print(f"{number} is an Armstrong number")
else:
    print(f"{number} is not an Armstrong number")
# Out:
# Please Enter a Number to Check if it is a Armstrong Number: -153
# It is an invalid entry. Don't use non-numeric, float, or negative values!
# Please Enter a Number to Check if it is a Armstrong Number: 121
# 121 is not an Armstrong number
